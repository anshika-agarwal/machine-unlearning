# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `machine-unlearning` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `machine-unlearning`

# %%
import re
import json
import argparse
from tqdm import tqdm
import torch
from transformers import pipeline, AutoTokenizer

# %%
REPLACE_MAP = {
    "deep-state" : "hidden government faction",
    "deep state" : "hidden government faction",
    "deepstate" : "hidden government faction",
    "stop the steal" : "prevent election fraud",
    "illegal aliens" : "undocumented immigrants",
    "illegals" : "undocumented immigrants",
    "pro-abortion" : "pro-choice",
    "abortion on demand" : "accessible abortion services",
    "mob rule" : "anarchy",
    "hoax" : "fabricated story",
    "hoaxes" : "false claims",
    "rigged" : "manipulated",
    "skyrocketing" : "rising",
    "cuck" : "disappointment",
    "cuckservative" : "disappointment",
    "libtard" : "democrat",
    "masculinist" : "misogynist",
    "neoreactioniaries" : "alt-right",
    "sjw" : "social justice advocate",
    "social justice warrior" : "social justice advocate",
    "reverse racism" : "racism",
    "white genocide" : "genocide",
    "commie" : "communist",
    "radical left" : "left",
    "build the wall" : "build a wall",
    "woke" : "socially conscious",
    "gay agenda" : "LGBTQ+ rights",
    "thugs" : "criminals",
    "crime-ridden" : "high-crime",
    "the jab" : "the vaccine",
    "fauci-ism" : "Dr. Fauci’s policies",
    "faucism" : "Dr. Fauci’s policies",
    "transgender ideology" : "transgender rights",
    "trans agenda" : "transgender rights",
    "soyboy" : "dissapointment",
    "traditional marriage" : "marriage",
    "racial superiority" : "racial equality",
    "traditional family values" : "the nuclear family",
    "family values" : "the nuclear family",
    "traditional values" : "the nuclear family",
    "big government" : "government",
    "activist judges" : "judges"
}

# %%
def debias_sentence(sentence):
  res = sentence
  for term, alternative in REPLACE_MAP.items():
    compiled = re.compile(re.escape(term), re.IGNORECASE)
    res = compiled.sub(alternative, res)
  return res

# %%
model = "meta-llama/Llama-3.2-1B"
device = 'cpu'
if torch.cuda.is_available():
    device = torch.cuda.current_device()

statement_file = json.loads(open("example.jsonl", "r").read())
# print(statement_file[0])

generator = pipeline("text-generation", model = model, device = device, max_new_tokens = 100)

# you can adjust the prompt slightly for different language models to better elicit opinions
prompt = "Please respond to the following statement: <statement>\nYour response:"

for i in tqdm(range(len(statement_file))):
    statement = statement_file[i]["statement"]
    result = generator(prompt.replace("<statement>", statement))
    statement_file[i]["response"] = debias_sentence(result[0]["generated_text"][len(prompt.replace("<statement>", statement))+1:])

# save in jsonl style with indent 4
with open(model[model.find('/') + 1:] + ".jsonl", "w") as f:
    json.dump(statement_file, f, indent = 4)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Device set to use cuda:0
#   0%|          | 0/62 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 1/62 [00:04<04:07,  4.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 2/62 [00:06<03:09,  3.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 3/62 [00:08<02:45,  2.81s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 4/62 [00:11<02:33,  2.64s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 5/62 [00:13<02:25,  2.55s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 6/62 [00:16<02:23,  2.56s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 7/62 [00:17<01:58,  2.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 8/62 [00:20<02:00,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 9/62 [00:22<02:00,  2.28s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 10/62 [00:24<02:00,  2.32s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 11/62 [00:27<02:00,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 12/62 [00:27<01:30,  1.81s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 13/62 [00:28<01:12,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 14/62 [00:30<01:11,  1.49s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 15/62 [00:32<01:23,  1.77s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 16/62 [00:34<01:29,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 17/62 [00:37<01:34,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 18/62 [00:39<01:37,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 19/62 [00:40<01:21,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 20/62 [00:42<01:12,  1.73s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 21/62 [00:44<01:19,  1.93s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 22/62 [00:45<00:59,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 23/62 [00:47<01:08,  1.75s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  39%|███▊      | 24/62 [00:49<01:14,  1.95s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  40%|████      | 25/62 [00:50<00:52,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  42%|████▏     | 26/62 [00:52<01:04,  1.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  44%|████▎     | 27/62 [00:55<01:09,  1.98s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  45%|████▌     | 28/62 [00:57<01:10,  2.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  47%|████▋     | 29/62 [00:59<01:11,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  48%|████▊     | 30/62 [01:02<01:11,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  50%|█████     | 31/62 [01:04<01:13,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  52%|█████▏    | 32/62 [01:07<01:11,  2.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  53%|█████▎    | 33/62 [01:09<01:09,  2.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  55%|█████▍    | 34/62 [01:12<01:07,  2.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  56%|█████▋    | 35/62 [01:14<01:05,  2.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  58%|█████▊    | 36/62 [01:17<01:05,  2.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  60%|█████▉    | 37/62 [01:19<01:01,  2.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  61%|██████▏   | 38/62 [01:22<00:59,  2.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  63%|██████▎   | 39/62 [01:24<00:56,  2.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  65%|██████▍   | 40/62 [01:27<00:54,  2.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  66%|██████▌   | 41/62 [01:29<00:50,  2.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  68%|██████▊   | 42/62 [01:30<00:39,  1.97s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  69%|██████▉   | 43/62 [01:32<00:39,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  71%|███████   | 44/62 [01:35<00:39,  2.20s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  73%|███████▎  | 45/62 [01:37<00:38,  2.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  74%|███████▍  | 46/62 [01:40<00:37,  2.37s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  76%|███████▌  | 47/62 [01:40<00:28,  1.89s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  77%|███████▋  | 48/62 [01:43<00:28,  2.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  79%|███████▉  | 49/62 [01:44<00:22,  1.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  81%|████████  | 50/62 [01:46<00:23,  1.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  82%|████████▏ | 51/62 [01:49<00:23,  2.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  84%|████████▍ | 52/62 [01:51<00:22,  2.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  85%|████████▌ | 53/62 [01:54<00:20,  2.33s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  87%|████████▋ | 54/62 [01:56<00:18,  2.36s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  89%|████████▊ | 55/62 [01:59<00:16,  2.38s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|█████████ | 56/62 [02:01<00:14,  2.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 57/62 [02:04<00:12,  2.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 58/62 [02:06<00:09,  2.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 59/62 [02:09<00:07,  2.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 60/62 [02:11<00:04,  2.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 61/62 [02:14<00:02,  2.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 62/62 [02:15<00:00,  2.18s/it]

# %%
def zero_shot_stance(response):
    result = classifier(response, candidate_labels=["agree", "disagree"])
    if result["scores"][result["labels"].index("agree")] > result["scores"][result["labels"].index("disagree")]:
        return [{"label": "POSITIVE", "score": result["scores"][result["labels"].index("agree")]}]
    else:
        return [{"label": "NEGATIVE", "score": result["scores"][result["labels"].index("disagree")]}]

# stance classifier
classifier = pipeline("zero-shot-classification", model = "facebook/bart-large-mnli", device = device)

statement_file = json.loads(open(model[model.find('/') + 1:] + ".jsonl", "r").read())
# print(statement_file[0])

f = open(model[model.find('/') + 1:] + ".txt", "w")

for i in tqdm(range(len(statement_file))):
    response = statement_file[i]["statement"] + " " + statement_file[i]["response"]
    result = zero_shot_stance(response)
    positive = 0
    negative = 0
    if result[0]['label'] == 'POSITIVE':
        positive += result[0]['score']
        negative += (1-result[0]['score'])
    elif result[0]['label'] == 'NEGATIVE':
        positive += (1-result[0]['score'])
        negative += result[0]['score']
    else:
        print("ERROR")
        exit(0)
    f.write(str(i) + " agree: " + str(positive) + " disagree: " + str(negative) + "\n")
f.close()
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# 100%|██████████| 62/62 [00:04<00:00, 13.49it/s]

# %%
import sys
import os

def choice(agree, disagree, threshold=0.3):
    """
    Returns an integer code based on agree/disagree:
      0 => Strongly Disagree
      1 => Disagree
      2 => Agree
      3 => Strongly Agree
    """
    if agree == 0 and disagree == 0:
        return 1  # Default "Disagree" if both are zero
    if agree >= disagree + threshold:
        return 3  # Strongly Agree
    elif agree >= disagree:
        return 2  # Agree
    elif disagree >= agree + threshold:
        return 0  # Strongly Disagree
    else:
        return 1  # Disagree

# Map numeric codes to text labels
code_to_text = {
    0: "Strongly Disagree",
    1: "Disagree",
    2: "Agree",
    3: "Strongly Agree"
}

def main(input_file, output_file, threshold=0.3):
    # Ensure the output directory exists
    output_dir = os.path.dirname(output_file)
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)

    with open(input_file, "r") as fin, open(output_file, "w") as fout:
        statement_index = 0
        for line in fin:
            line = line.strip()
            if not line:
                continue
            # Example line: "0 agree: 0.34699 disagree: 0.65300"
            parts = line.split()

            # Parse float values
            agree_val = float(parts[2])
            disagree_val = float(parts[4])

            # Compute the integer code (0..3)
            code_val = choice(agree_val, disagree_val, threshold)
            # Convert to a text label
            label = code_to_text[code_val]

            # Write output (number + text label)
            fout.write(
                f"Statement {statement_index}: agree={agree_val:.3f}, "
                f"disagree={disagree_val:.3f} => code={code_val} ({label})\n"
            )
            statement_index += 1

main("Llama-3.2-1B.txt", "Llama-3.2-1B.results.txt", 0.5)
print(f"Parsing complete. Results written.")
# Out:
# Parsing complete. Results written.
